# %%
import tweepy
import csv

# %%
# import api key dan access token di developer tweepy, digunakan untuk OAuth
api_key="apydfIpmVmm3iN3g4VQ0wtghs"
api_key_secret="vs5A25uAeIwmEAYnfNeVhW39BHZsZFMZcxkbXvwxXW4Xo6UdtH"

access_token="967982873004335106-axnPLB4OD0UJdA51YoTsMyo7GnKHVNq"
access_token_secret="3KThifrUbau85UWFrw5eUqW6kiM7L6p0NFv7IPcx0XRQC"

# %%
# proses OAuth, menggunakan kunci and token yang disimpan pada variabel sebelumnya
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)
sleep_on_rate_limit=False

# %%
kata_kunci = "dokternya OR susternya"
tweets = tweepy.Cursor(api.search,q=kata_kunci,lang="id",result_type="mixed",tweet_mode="extended").items(1800)

# %%
# membuat file hasil pengambilan data
tweet_set = open("medictreat2.csv", "w", encoding="utf-8")
writer = csv.writer(tweet_set)

# header dari file csv yang akan dibuat
writer.writerow(['date','username','fulltext'])

# menulis tweet tiap baris
for item in tweets:
    writer.writerow([item.created_at, item.author.screen_name, item.full_text])
    print([item.created_at, item.author.screen_name, item.full_text])
# Out:
# [datetime.datetime(2022, 3, 8, 15, 30, 16), 'Pluviophile_Arn', '@sagipussy Anjir wkwwkwkkw dokternya auto ngeuh🤣']
# [datetime.datetime(2022, 3, 8, 15, 27, 5), 'aa_anting', '@PalingDepan__ Bukan mksdnya yg ke ruang icu nanyain kondisi andin ke dokternya. Ada?']
# [datetime.datetime(2022, 3, 8, 15, 25, 38), 'ayukaaa9', 'Pas lahir juga ga nangis. Yaa dokternya sibuk lgi operasi di tempat lain. Suster/bidannya pun ga berani nanganin gegara sungsang']
# [datetime.datetime(2022, 3, 8, 15, 23, 41), 'VeramitaNanda', "Trs ada lagi, pas kuliah fisiologi persarafan ke kandung kemih dan rectum. Trs dokternya blg\n'Ngebrok'\nIt's mean, BAB tanpa disadari krn perasarafannya rusak, jd g ada rasa ingin bab tbtb bab\n\nTmnku nanya 'artinya ngebrok apa woy, masa sama bahasa medisnya susah bhs jawanya' 🤣🤣"]
# [datetime.datetime(2022, 3, 8, 15, 22, 31), 'recycledump', 'dokternya bilang gigiku cantik tapi sambil ketawa 😙😐 https://t.co/eaNLE2PDfS']
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48500/2548746589.py in <module>
#       1 import tweepy
# ----> 2 from textblob import TextBlob
#       3 from wordcloud import WordCloud
#       4 import pandas as pd
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'textblob'
