# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# **IMPORT DATASET LABELING**

# %%
data = pd.read_excel('/content/dataset-labeling fix.xlsx')
data
# Out:
#       Unnamed: 0                                       tweet_cleans  \
# 0              0               anjir wkwwkwkkw dokternya auto ngeuh
# 1              1  mksdnya yg ruang icu nanyain kondisi andin dok...
# 2              2  pas lahir ga nangis yaa dokternya sibuk lgi op...
# 3              3  trs pas kuliah fisiologi persarafan kandung ke...
# 4              4              dokternya bilang gigiku cantik ketawa
# ...          ...                                                ...
# 3954        4131  perawat ogut knp pasien dokternya tacut pdhl a...
# 3955        4132  pas dokternya jelasin diagnosanya gw ngelamun ...
# 3956        4133  semoga kesembuhan beb temenin makan sehat deh ...
# 3957        4134  gw daritadi udah minum botol aqua ga kasian do...
# 3958        4135  habis tht ngerasa pendengaran qoq aga berkuran...
#
#                                           tweet_english klasifikasi
# 0                     fig wkwwkwkkw the doctor auto nod      Netral
# ...

# %% [markdown]
# **HAPUS COLUMN YANG TIDAK PERLU**

# %%
data.drop(['tweet_english'], axis=1, inplace=True)
data
# Out:
#       Unnamed: 0                                       tweet_cleans  \
# 0              0               anjir wkwwkwkkw dokternya auto ngeuh
# 1              1  mksdnya yg ruang icu nanyain kondisi andin dok...
# 2              2  pas lahir ga nangis yaa dokternya sibuk lgi op...
# 3              3  trs pas kuliah fisiologi persarafan kandung ke...
# 4              4              dokternya bilang gigiku cantik ketawa
# ...          ...                                                ...
# 3954        4131  perawat ogut knp pasien dokternya tacut pdhl a...
# 3955        4132  pas dokternya jelasin diagnosanya gw ngelamun ...
# 3956        4133  semoga kesembuhan beb temenin makan sehat deh ...
# 3957        4134  gw daritadi udah minum botol aqua ga kasian do...
# 3958        4135  habis tht ngerasa pendengaran qoq aga berkuran...
#
#      klasifikasi
# 0         Netral
# 1        Negatif
# 2        Positif
# 3         Netral
# 4        Positif
# ...          ...
# 3954     Positif
# ...

# %% [markdown]
# **ADA BEBERAPA YANG DUPLIKAT KARNA ITU HARUS MENJALANKAN FUNCTION DEL DUPLICATE TEXT**

# %%
data.drop_duplicates(subset = "tweet_cleans", keep = "first", inplace=True)
data
# Out:
#       Unnamed: 0                                       tweet_cleans  \
# 0              0               anjir wkwwkwkkw dokternya auto ngeuh
# 1              1  mksdnya yg ruang icu nanyain kondisi andin dok...
# 2              2  pas lahir ga nangis yaa dokternya sibuk lgi op...
# 3              3  trs pas kuliah fisiologi persarafan kandung ke...
# 4              4              dokternya bilang gigiku cantik ketawa
# ...          ...                                                ...
# 2588        2765     capek banget bisanya meluk dokternya crazylove
# 2590        2767  trims mom kek gini penjelasannya aq paham dokt...
# 2591        2768                              aaaaa merem dokternya
# 3275        3452  buru dibawa takut flutd gapapa kucing ku takut...
# 3420        3597  kalo kucingnya steril ditaruh kamar ruang gera...
#
#      klasifikasi
# 0         Netral
# 1        Negatif
# 2        Positif
# 3         Netral
# 4        Positif
# ...          ...
# 2588     Negatif
# ...

# %% [markdown]
# **SIMPAN DATASET FIX**

# %%
data.to_excel('./dataset-label-sudah-bersih.xlsx', encoding='utf8', index=True)
